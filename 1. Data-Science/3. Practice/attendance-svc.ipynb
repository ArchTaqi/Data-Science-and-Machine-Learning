# %%
import pymysql
from sqlalchemy import create_engine
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from datetime import datetime


engine = create_engine('mysql+pymysql://muhammadtaqi:Nopass2018!@127.0.0.1:3306/attendance_svc')
data = pd.read_sql_query("SELECT * FROM request where date_from >= '2018-12-10' and date_to <=  '2018-12-10' ", engine)

# %%
df = data.copy()
df.set_index('id',inplace=True)
df.tail()
# Out:
#                             approver_user_id  \
# id
# 136307  6bc884a4-8673-470d-ab06-421c12d962b0
# 137544  364d93de-f7f8-42bf-b006-600dd444dd47
# 137611  b727cba6-e739-7116-c646-6c24c1d1fa4a
# 139236                                  None
#
#                          preapprover_user_id  \
# id
# 136307  10f5bee6-4e3c-4b6d-a8cb-37e658ea5b3f
# 137544                                  None
# 137611                                  None
# 139236                                  None
#
#                                      user_id      type           subtype  \
# id
# 136307  283b1aa7-0e6f-fc3c-138a-98d77aef2adc  vacation  vacation-regular
# 137544  e6137ab1-36a9-41de-8cad-570130fb8569  vacation  vacation-regular
# 137611  b70e38e6-272b-871b-7a76-01b982baa860  vacation  vacation-regular
# 139236  a1bf66ff-c37f-44b0-84de-26cc326b4d76  vacation  vacation-regular
#
#           status   date_from     date_to time_from  work_duration  \
# id
# ...

# %%
pp = pd.value_counts(df.dtypes)
pp.plot.bar()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 8.27))
sns.countplot(x='type', data = df)
