# %% [markdown]
# # Assignment 5 Basic Wrangling

# %% [markdown]
# Do the basic data wrangling that we performed in class on the given data set **fifa.csv**.
#
# - Basic Data Exploration
# - Missing Values
# - Duplicates
# - Selecting / Dropping Columns
# - String operations on whole columns
# - Column splits/transformations

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('fifa.csv')

# %% [markdown]
# # 1. Basic Data Exploration

# %%
df.head(5)
# Out:
#        id                     name   rating  position   height    foot   rare  \
# 0    1001             Gábor Király       69        GK      191   Right      0
# 1  100143             Frederik Boi       65         M      184   Right      0
# 2  100264          Tomasz Szewczuk       57         A      185   Right      0
# 3  100325   Steeve Joseph-Reinette       63         D      180    Left      0
# 4  100326             Kamel Chafni       72         M      181   Right      0
#
#    pace  shooting  passing  dribbling  defending  heading  diving  handling  \
# 0                                                              70        66
# 1    61        65       63         59         62       62
# 2    65        54       43         53         55       74
# 3    68        38       51         46         64       71
# 4    75        64       67         72         57       66
#
#    kicking  reflexes  speed   positioning
# 0       63        74     35          66.0
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN

# %% [markdown]
# ** Change index of dataset **

# %% [markdown]
# Before changing index verify that the new index column has has no duplicates

# %%
df.duplicated(['id']).sum()
# Out:
# 0

# %% [markdown]
# AS column **_id_** has no duplicates, so we can safely set it as our index.

# %%
df.set_index('id',inplace=True)

# %%
df.index[df.index.duplicated()].unique()
# Out:
# Int64Index([], dtype='int64', name='id')

# %%
df.head(5)
# Out:
#                            name   rating  position   height    foot   rare  \
# id
# 1001               Gábor Király       69        GK      191   Right      0
# 100143             Frederik Boi       65         M      184   Right      0
# 100264          Tomasz Szewczuk       57         A      185   Right      0
# 100325   Steeve Joseph-Reinette       63         D      180    Left      0
# 100326             Kamel Chafni       72         M      181   Right      0
#
#         pace  shooting  passing  dribbling  defending  heading  diving  \
# id
# 1001                                                                70
# 100143    61        65       63         59         62       62
# 100264    65        54       43         53         55       74
# 100325    68        38       51         46         64       71
# 100326    75        64       67         72         57       66
#
#         handling  kicking  reflexes  speed   positioning
# id
# 1001          66       63        74     35          66.0
# 100143                                               NaN
# 100264                                               NaN
# 100325                                               NaN
# 100326                                               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8847 entries, 1001 to 9913
# Data columns (total 18 columns):
#  name           8847 non-null object
#  rating         8847 non-null int64
#  position       8847 non-null object
#  height         8847 non-null int64
#  foot           8847 non-null object
#  rare           8847 non-null int64
#  pace           8847 non-null object
#  shooting       8847 non-null object
#  passing        8847 non-null object
#  dribbling      8847 non-null object
#  defending      8847 non-null object
#  heading        8847 non-null object
#  diving         8847 non-null object
#  handling       8847 non-null object
#  kicking        8847 non-null object
#  reflexes       8847 non-null object
#  speed          8847 non-null object
#  positioning    930 non-null float64
# dtypes: float64(1), int64(3), object(14)
# memory usage: 1.6+ MB

# %%
df.columns
# Out:
# Index([' name', ' rating', ' position', ' height', ' foot', ' rare', ' pace',
#        ' shooting', ' passing', ' dribbling', ' defending', ' heading',
#        ' diving', ' handling', ' kicking', ' reflexes', ' speed',
#        ' positioning'],
#       dtype='object')

# %% [markdown]
# AS we see columns have spaces in the begining, we have to remove these spaces.

# %%
columns = list(df.columns)
columns
columns = [x.strip(' ') for x in columns]
df.columns = columns

# %%
df.head(5)
# Out:
#                            name  rating position  height    foot  rare pace  \
# id
# 1001               Gábor Király      69       GK     191   Right     0
# 100143             Frederik Boi      65        M     184   Right     0   61
# 100264          Tomasz Szewczuk      57        A     185   Right     0   65
# 100325   Steeve Joseph-Reinette      63        D     180    Left     0   68
# 100326             Kamel Chafni      72        M     181   Right     0   75
#
#        shooting passing dribbling defending heading diving handling kicking  \
# id
# 1001                                                    70       66      63
# 100143       65      63        59        62      62
# 100264       54      43        53        55      74
# 100325       38      51        46        64      71
# 100326       64      67        72        57      66
#
#        reflexes speed  positioning
# id
# 1001         74    35         66.0
# 100143                         NaN
# 100264                         NaN
# 100325                         NaN
# 100326                         NaN

# %% [markdown]
# # 2. Missing Values

# %%
df.isnull().sum()
# Out:
# name              0
# rating            0
# position          0
# height            0
# foot              0
# rare              0
# pace              0
# shooting          0
# passing           0
# dribbling         0
# defending         0
# heading           0
# diving            0
# handling          0
# kicking           0
# reflexes          0
# speed             0
# positioning    7917
# dtype: int64

# %%
# Replace `NaN` values with the mean of the column
df.fillna(df.mean(), inplace=True)
df.isnull().sum()
# Out:
# name           0
# rating         0
# position       0
# height         0
# foot           0
# rare           0
# pace           0
# shooting       0
# passing        0
# dribbling      0
# defending      0
# heading        0
# diving         0
# handling       0
# kicking        0
# reflexes       0
# speed          0
# positioning    0
# dtype: int64

# %%
df.head(10)
# Out:
#                            name  rating position  height    foot  rare pace  \
# id
# 1001               Gábor Király      69       GK     191   Right     0
# 100143             Frederik Boi      65        M     184   Right     0   61
# 100264          Tomasz Szewczuk      57        A     185   Right     0   65
# 100325   Steeve Joseph-Reinette      63        D     180    Left     0   68
# 100326             Kamel Chafni      72        M     181   Right     0   75
# 100329           Abdoulaye Faye      72        D     187   Right     1   50
# 100330                José Saez      67        M     170   Right     0   53
# 100391          Laurent Delorge      67        M     179   Right     0   76
# 100521              David Noble      64        M     183   Right     1   62
# 100522            Dominic Foley      62        A     186    Left     1   34
#
#        shooting passing dribbling defending heading diving handling kicking  \
# id
# 1001                                                    70       66      63
# 100143       65      63        59        62      62
# 100264       54      43        53        55      74
# 100325       38      51        46        64      71
# 100326       64      67        72        57      66
# 100329       37      47        43        76      82
# 100330       60      65        61        64      60
# 100391       58      67        64        63      56
# 100521       52      66        65        56      53
# 100522       65      55        55        56      77
#
#        reflexes speed  positioning
# id
# 1001         74    35    66.000000
# 100143                   64.955914
# 100264                   64.955914
# 100325                   64.955914
# 100326                   64.955914
# 100329                   64.955914
# 100330                   64.955914
# 100391                   64.955914
# 100521                   64.955914
# 100522                   64.955914

# %% [markdown]
# # 3. Duplicates

# %%
df.name[df.name.duplicated()].unique()
# Out:
# array([' Juanma', ' Damien Perquis', ' Adriano', ' Diego', ' Lúcio',
#        ' Kléber', ' David García', ' Ricardo', ' Corona', ' Juanfran',
#        ' Cristian', ' Peña', ' Rubén', ' Rodri', ' Luciano', ' Alex',
#        ' Maicon', ' Amaya', ' Paul Robinson', ' Roberto', ' Stephen Hunt',
#        ' Mauricio Romero', ' Milan Jovanović', ' Souza', ' Sergio',
#        ' Eduardo', " James O'Connor", ' Caio', ' Cássio', ' Júlio César',
#        ' Anderson', ' Mark Hughes', ' Sastre', ' João Paulo', ' Varela',
#        ' Wayne Brown', ' Gonzalo Castro', ' Gilberto', ' Ayoze',
#        ' Lee Sang Ho', ' Marcelo', ' Ben Smith', ' Henrique',
#        ' Andy Williams', ' Gary Roberts', ' Bruno', ' Rafinha',
#        ' Marco Rossi', ' Marcos', ' Nenê', ' Fred', ' Emerson', ' Lima',
#        ' Guilherme', ' Jonas', ' Felipe', ' Everton', ' Adi', ' Cris',
#        ' William', ' David González', ' Ángel', ' Chris Martin',
#        ' Fabiano', ' Charles', ' Tommy Smith', ' Alberto', ' Elias',
#        ' Diogo', ' Zé Eduardo', ' Wellington', ' Douglas',
#        ' Matthew Taylor', ' Peter Murphy', ' Saúl', ' Ashley Westwood',
#        ' Susaeta', ' Fábio', ' Rafael', ' Renan', ' Samuel', ' Oier',
#        ' Míchel', ' Bernardo', ' Wesley', ' Cicinho', ' Kike', ' Galán',
#        ' André Santos', ' Juan Dominguez', ' Roger', " Mark O'Brien",
#        ' Toni', ' Raúl', ' Willian', ' Billy Jones', ' Juninho',
#        ' Llorente', ' Rodrigo', ' Fabricio', ' Michel', ' Danilo',
#        ' Kanu', ' Josué', ' Paulinho', ' Lucas', ' Diego Jiménez',
#        ' Miranda', ' James Henry', ' Juan Carlos', ' Gabriel',
#        ' Lee Yong', ' Mike Jones', ' Chris Taylor', ' Adam Smith',
#        ' Antonio López', ' Tiago', ' Leonardo', ' Ryan Taylor',
#        ' Andreas Johansson', ' Capdevila', ' Gaspar', ' Moreira',
#        ' André Luiz', ' Rivaldo', ' Juan', ' Leandro', ' Mark Wilson',
#        ' Nano', ' Fernando Navarro', ' Portillo'], dtype=object)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [name, rating, position, height, foot, rare, pace, shooting, passing, dribbling, defending, heading, diving, handling, kicking, reflexes, speed, positioning]
# Index: []

# %% [markdown]
# # 4. Selecting / Dropping Columns

# %%
df[df.foot == ' Right']
# Out:
#                        name  rating position  height    foot  rare pace  \
# id
# 1001           Gábor Király      69       GK     191   Right     0
# 100143         Frederik Boi      65        M     184   Right     0   61
# 100264      Tomasz Szewczuk      57        A     185   Right     0   65
# 100326         Kamel Chafni      72        M     181   Right     0   75
# 100329       Abdoulaye Faye      72        D     187   Right     1   50
# 100330            José Saez      67        M     170   Right     0   53
# 100391      Laurent Delorge      67        M     179   Right     0   76
# 100521          David Noble      64        M     183   Right     1   62
# 100559         Paul McKenna      68        M     170   Right     0   53
# 100574         Paweł Abbott      59        A     187   Right     0   51
# 100578    Richard Cresswell      66        A     183   Right     1   56
# 100580          David Healy      69        A     173   Right     0   64
# 100585        Dickson Etuhu      75        M     188   Right     1   59
# 100670      Ashley Westwood      54        D     183   Right     0   47
# 100701           Paul Ifill      70        A     180   Right     0   72
# 100707         David Artell      59        D     188   Right     0   48
# 100743      Martin Rowlands      64        M     175   Right     1   52
# 100745           Paul Smith      64       GK     193   Right     1
# 100751       Kevin O'Connor      59        D     180   Right     0   53
# 100792   Brynjar Gunnarsson      61        M     183   Right     0   34
# 100798       James O'Connor      63        M     173   Right     0   61
# 100803           Karl Henry      71        M     185   Right     0   55
# 100807    Stefanos Kotsolis      65       GK     190   Right     0
# 100889          Louis Carey      67        D     178   Right     0   45
# 100899       Steve Phillips      61       GK     185   Right     1
# 100907          Danny Coles      62        D     185   Right     0   70
# 100932   Sotirios Kyrgiakos      76        D     193   Right     1   41
# 100954         Monsef Zerka      63        M     183   Right     0   69
# 100964         Romain Poyet      72        A     184   Right     1   68
# 101160     Nicoló Consolini      63        D     180   Right     0   71
# ...                     ...     ...      ...     ...     ...   ...  ...
# 8473          Tomáš Rosický      81        M     179   Right     1   68
# 8517           Scott Parker      82        M     175   Right     1   73
# 860             Danny Senda      57        D     178   Right     0   70
# 8753               Omar Daf      68        D     177   Right     0   61
# 878         Danny Schofield      64        M     178   Right     0   64
# 8798                Movilla      69        M     171   Right     0   45
# 880               Nat Brown      57        D     188   Right     0   53
# 882        John Thorrington      63        M     173   Right     1   68
# 8830       Giuseppe Colucci      72        M     179   Right     1   57
# 8842         Lionel Scaloni      68        D     182   Right     0   52
# 885           Dwayne Mattis      64        M     183   Right     0   72
# 887           Nathan Clarke      62        D     185   Right     0   56
# 889             Jody Morris      66        M     165   Right     0   64
# 8910             Carlo Nash      63       GK     182   Right     1
# 899              Frank Rost      74       GK     194   Right     1
# 9037                 Rufete      67        M     176   Right     0   58
# 9195         Pantelis Kafes      70        M     180   Right     1   66
# 9232      Tomasz Frankowski      68        A     172   Right     0   59
# 9273      Thorstein Helstad      70        A     187   Right     1   53
# 9432         Yossi Benayoun      82        M     178   Right     0   71
# 9639             Aitor Ocio      72        D     187   Right     0   32
# 9676           Samuel Eto'o      88        A     180   Right     1   93
# 9722       Nicolai Stokholm      67        M     182   Right     0   59
# 9723           Camel Meriem      71        M     174   Right     0   58
# 9751            Gábor Babos      71       GK     196   Right     1
# 9799      Pierre-Alain Frau      73        A     175   Right     1   79
# 9805          Craig Bellamy      79        A     175   Right     0   80
# 9807          Michel Breuer      68        D     183   Right     0   61
# 9815            Gill Swerts      65        D     179   Right     0   65
# 9913            Mehdi Nafti      69        M     179   Right     0   55
#
#        shooting passing dribbling defending heading diving handling kicking  \
# id
# 1001                                                    70       66      63
# 100143       65      63        59        62      62
# 100264       54      43        53        55      74
# 100326       64      67        72        57      66
# 100329       37      47        43        76      82
# 100330       60      65        61        64      60
# 100391       58      67        64        63      56
# 100521       52      66        65        56      53
# 100559       65      68        63        70      69
# 100574       60      49        51        54      64
# 100578       63      53        49        62      72
# 100580       72      51        60        48      69
# 100585       55      64        63        80      72
# 100670       26      39        40        62      57
# 100701       65      59        78        54      52
# 100707       27      38        36        65      68
# 100743       60      66        66        63      59
# 100745                                                  65       62      55
# 100751       48      60        53        62      55
# 100792       54      61        65        68      66
# 100798       53      61        60        68      70
# 100803       57      71        71        73      64
# 100807                                                  62       68      62
# 100889       31      45        38        69      78
# 100899                                                  46       65      76
# 100907       32      33        35        66      67
# 100932       42      46        38        80      80
# 100954       60      59        64        53      63
# 100964       70      70        73        56      74
# 101160       47      60        57        63      58
# ...         ...     ...       ...       ...     ...    ...      ...     ...
# 8473         75      81        84        50      52
# 8517         76      81        76        78      74
# 860          44      61        59        60      63
# 8753         38      62        47        72      69
# 878          58      62        61        56      59
# 8798         57      72        56        66      53
# 880          32      39        38        62      69
# 882          64      61        64        62      63
# 8830         69      74        69        66      53
# 8842         65      71        68        70      60
# 885          47      57        53        68      58
# 887          26      40        35        67      64
# 889          50      62        73        60      58
# 8910                                                    60       66      60
# 899                                                     72       74      70
# 9037         64      72        71        59      48
# 9195         72      73        74        68      63
# 9232         67      48        60        42      66
# 9273         72      61        69        58      73
# 9432         73      76        82        55      60
# 9639         47      64        56        73      62
# 9676         83      68        85        58      79
# 9722         67      71        56        70      70
# 9723         65      69        75        45      62
# 9751                                                    70       70      60
# 9799         72      68        71        54      68
# 9805         78      67        81        62      71
# 9807         40      56        51        70      74
# 9815         48      63        65        67      69
# 9913         56      64        65        69      60
#
#        reflexes speed  positioning
# id
# 1001         74    35    66.000000
# 100143                   64.955914
# 100264                   64.955914
# 100326                   64.955914
# 100329                   64.955914
# 100330                   64.955914
# 100391                   64.955914
# 100521                   64.955914
# 100559                   64.955914
# 100574                   64.955914
# 100578                   64.955914
# 100580                   64.955914
# 100585                   64.955914
# 100670                   64.955914
# 100701                   64.955914
# 100707                   64.955914
# 100743                   64.955914
# 100745       67    41    62.000000
# 100751                   64.955914
# 100792                   64.955914
# 100798                   64.955914
# 100803                   64.955914
# 100807       65    60    64.000000
# 100889                   64.955914
# 100899       71    31    61.000000
# 100907                   64.955914
# 100932                   64.955914
# 100954                   64.955914
# 100964                   64.955914
# 101160                   64.955914
# ...         ...   ...          ...
# 8473                     64.955914
# 8517                     64.955914
# 860                      64.955914
# 8753                     64.955914
# 878                      64.955914
# 8798                     64.955914
# 880                      64.955914
# 882                      64.955914
# 8830                     64.955914
# 8842                     64.955914
# 885                      64.955914
# 887                      64.955914
# 889                      64.955914
# 8910         63    45    64.000000
# 899          75    32    80.000000
# 9037                     64.955914
# 9195                     64.955914
# 9232                     64.955914
# 9273                     64.955914
# 9432                     64.955914
# 9639                     64.955914
# 9676                     64.955914
# 9722                     64.955914
# 9723                     64.955914
# 9751         70    29    75.000000
# 9799                     64.955914
# 9805                     64.955914
# 9807                     64.955914
# 9815                     64.955914
# 9913                     64.955914
#
# [6762 rows x 18 columns]

# %%
df[df.height >= 150]
# Out:
#                            name  rating position  height    foot  rare pace  \
# id
# 1001               Gábor Király      69       GK     191   Right     0
# 100143             Frederik Boi      65        M     184   Right     0   61
# 100264          Tomasz Szewczuk      57        A     185   Right     0   65
# 100325   Steeve Joseph-Reinette      63        D     180    Left     0   68
# 100326             Kamel Chafni      72        M     181   Right     0   75
# 100329           Abdoulaye Faye      72        D     187   Right     1   50
# 100330                José Saez      67        M     170   Right     0   53
# 100391          Laurent Delorge      67        M     179   Right     0   76
# 100521              David Noble      64        M     183   Right     1   62
# 100522            Dominic Foley      62        A     186    Left     1   34
# 100557       Brian Barry-Murphy      60        M     185    Left     0   61
# 100559             Paul McKenna      68        M     170   Right     0   53
# 100574             Paweł Abbott      59        A     187   Right     0   51
# 100578        Richard Cresswell      66        A     183   Right     1   56
# 100580              David Healy      69        A     173   Right     0   64
# 100585            Dickson Etuhu      75        M     188   Right     1   59
# 100670          Ashley Westwood      54        D     183   Right     0   47
# 100701               Paul Ifill      70        A     180   Right     0   72
# 100707             David Artell      59        D     188   Right     0   48
# 100743          Martin Rowlands      64        M     175   Right     1   52
# 100745               Paul Smith      64       GK     193   Right     1
# 100751           Kevin O'Connor      59        D     180   Right     0   53
# 100756             Stephen Hunt      56        D     185    Left     0   67
# 100758                 Jay Tabb      63        M     170    Left     1   69
# 100792       Brynjar Gunnarsson      61        M     183   Right     0   34
# 100798           James O'Connor      63        M     173   Right     0   61
# 100803               Karl Henry      71        M     185   Right     0   55
# 100804              Gareth Owen      62        D     185    Left     0   61
# 100806             Kris Commons      75        M     168    Left     0   79
# 100807        Stefanos Kotsolis      65       GK     190   Right     0
# ...                         ...     ...      ...     ...     ...   ...  ...
# 8753                   Omar Daf      68        D     177   Right     0   61
# 878             Danny Schofield      64        M     178   Right     0   64
# 8798                    Movilla      69        M     171   Right     0   45
# 880                   Nat Brown      57        D     188   Right     0   53
# 882            John Thorrington      63        M     173   Right     1   68
# 8830           Giuseppe Colucci      72        M     179   Right     1   57
# 8842             Lionel Scaloni      68        D     182   Right     0   52
# 885               Dwayne Mattis      64        M     183   Right     0   72
# 887               Nathan Clarke      62        D     185   Right     0   56
# 889                 Jody Morris      66        M     165   Right     0   64
# 8910                 Carlo Nash      63       GK     182   Right     1
# 899                  Frank Rost      74       GK     194   Right     1
# 9014               Arjen Robben      90        M     181    Left     1   93
# 9037                     Rufete      67        M     176   Right     0   58
# 9195             Pantelis Kafes      70        M     180   Right     1   66
# 9232          Tomasz Frankowski      68        A     172   Right     0   59
# 9273          Thorstein Helstad      70        A     187   Right     1   53
# 9432             Yossi Benayoun      82        M     178   Right     0   71
# 9639                 Aitor Ocio      72        D     187   Right     0   32
# 9676               Samuel Eto'o      88        A     180   Right     1   93
# 9722           Nicolai Stokholm      67        M     182   Right     0   59
# 9723               Camel Meriem      71        M     174   Right     0   58
# 9751                Gábor Babos      71       GK     196   Right     1
# 9771           Orlando Engelaar      73        M     196    Left     1   38
# 9799          Pierre-Alain Frau      73        A     175   Right     1   79
# 9801            Danijel Ljuboja      73        A     189    Left     1   62
# 9805              Craig Bellamy      79        A     175   Right     0   80
# 9807              Michel Breuer      68        D     183   Right     0   61
# 9815                Gill Swerts      65        D     179   Right     0   65
# 9913                Mehdi Nafti      69        M     179   Right     0   55
#
#        shooting passing dribbling defending heading diving handling kicking  \
# id
# 1001                                                    70       66      63
# 100143       65      63        59        62      62
# 100264       54      43        53        55      74
# 100325       38      51        46        64      71
# 100326       64      67        72        57      66
# 100329       37      47        43        76      82
# 100330       60      65        61        64      60
# 100391       58      67        64        63      56
# 100521       52      66        65        56      53
# 100522       65      55        55        56      77
# 100557       54      60        47        60      48
# 100559       65      68        63        70      69
# 100574       60      49        51        54      64
# 100578       63      53        49        62      72
# 100580       72      51        60        48      69
# 100585       55      64        63        80      72
# 100670       26      39        40        62      57
# 100701       65      59        78        54      52
# 100707       27      38        36        65      68
# 100743       60      66        66        63      59
# 100745                                                  65       62      55
# 100751       48      60        53        62      55
# 100756       32      46        46        59      63
# 100758       58      66        65        59      66
# 100792       54      61        65        68      66
# 100798       53      61        60        68      70
# 100803       57      71        71        73      64
# 100804       19      48        46        65      67
# 100806       74      73        80        48      60
# 100807                                                  62       68      62
# ...         ...     ...       ...       ...     ...    ...      ...     ...
# 8753         38      62        47        72      69
# 878          58      62        61        56      59
# 8798         57      72        56        66      53
# 880          32      39        38        62      69
# 882          64      61        64        62      63
# 8830         69      74        69        66      53
# 8842         65      71        68        70      60
# 885          47      57        53        68      58
# 887          26      40        35        67      64
# 889          50      62        73        60      58
# 8910                                                    60       66      60
# 899                                                     72       74      70
# 9014         85      81        93        53      60
# 9037         64      72        71        59      48
# 9195         72      73        74        68      63
# 9232         67      48        60        42      66
# 9273         72      61        69        58      73
# 9432         73      76        82        55      60
# 9639         47      64        56        73      62
# 9676         83      68        85        58      79
# 9722         67      71        56        70      70
# 9723         65      69        75        45      62
# 9751                                                    70       70      60
# 9771         71      71        65        75      61
# 9799         72      68        71        54      68
# 9801         73      64        74        56      68
# 9805         78      67        81        62      71
# 9807         40      56        51        70      74
# 9815         48      63        65        67      69
# 9913         56      64        65        69      60
#
#        reflexes speed  positioning
# id
# 1001         74    35    66.000000
# 100143                   64.955914
# 100264                   64.955914
# 100325                   64.955914
# 100326                   64.955914
# 100329                   64.955914
# 100330                   64.955914
# 100391                   64.955914
# 100521                   64.955914
# 100522                   64.955914
# 100557                   64.955914
# 100559                   64.955914
# 100574                   64.955914
# 100578                   64.955914
# 100580                   64.955914
# 100585                   64.955914
# 100670                   64.955914
# 100701                   64.955914
# 100707                   64.955914
# 100743                   64.955914
# 100745       67    41    62.000000
# 100751                   64.955914
# 100756                   64.955914
# 100758                   64.955914
# 100792                   64.955914
# 100798                   64.955914
# 100803                   64.955914
# 100804                   64.955914
# 100806                   64.955914
# 100807       65    60    64.000000
# ...         ...   ...          ...
# 8753                     64.955914
# 878                      64.955914
# 8798                     64.955914
# 880                      64.955914
# 882                      64.955914
# 8830                     64.955914
# 8842                     64.955914
# 885                      64.955914
# 887                      64.955914
# 889                      64.955914
# 8910         63    45    64.000000
# 899          75    32    80.000000
# 9014                     64.955914
# 9037                     64.955914
# 9195                     64.955914
# 9232                     64.955914
# 9273                     64.955914
# 9432                     64.955914
# 9639                     64.955914
# 9676                     64.955914
# 9722                     64.955914
# 9723                     64.955914
# 9751         70    29    75.000000
# 9771                     64.955914
# 9799                     64.955914
# 9801                     64.955914
# 9805                     64.955914
# 9807                     64.955914
# 9815                     64.955914
# 9913                     64.955914
#
# [8847 rows x 18 columns]

# %% [markdown]
# # 5. String operations on whole columns

# %%
df.foot.unique()
# Out:
# array([' Right', ' Left'], dtype=object)

# %%
df.foot = df.foot.str.replace(' Right', 'Right')
df.foot = df.foot.str.replace(' Left', 'Left')
df.foot.unique()
# Out:
# array(['Right', 'Left'], dtype=object)

# %%
df.position.unique()
# Out:
# array([' GK', ' M', ' A', ' D'], dtype=object)

# %%
df.position = [x.strip(' ') for x in df.position]

df.position.unique()
# Out:
# array(['GK', 'M', 'A', 'D'], dtype=object)

# %%
df.name.unique()
# Out:
# array([' Gábor Király', ' Frederik Boi', ' Tomasz Szewczuk', ...,
#        ' Michel Breuer', ' Gill Swerts', ' Mehdi Nafti'], dtype=object)

# %%
df.name = [x.strip(' ') for x in df.name]

df.name.unique()
# Out:
# array(['Gábor Király', 'Frederik Boi', 'Tomasz Szewczuk', ...,
#        'Michel Breuer', 'Gill Swerts', 'Mehdi Nafti'], dtype=object)

# %% [markdown]
# # 6. Column splits/transformations

# %%
df.rating.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2d3ae8910121> in <module>()
# ----> 1 df.rating.unique()
#
# NameError: name 'df' is not defined

# %%
new = df.groupby(['name', 'position'])['rating'].mean().reset_index()
new.sort_values(['name', 'position'], ascending=[True, False], inplace=True)
new
# Out:
#                         name position  rating
# 0             A.J. DeLaGarza        D    66.0
# 1                A.J. Soares        D    62.0
# 2                      Aaron        A    66.0
# 3                Aaron Brown        D    55.0
# 4            Aaron Cresswell        D    64.0
# 5                Aaron Doran        M    65.0
# 6                Aaron Forde        M    45.0
# 7               Aaron Greene        A    58.0
# 8               Aaron Hughes        D    76.0
# 9                 Aaron Hunt        M    75.0
# 10              Aaron Lennon        M    82.0
# 11              Aaron Martin        D    64.0
# 12             Aaron McCarey       GK    59.0
# 13              Aaron McLean        A    66.0
# 14             Aaron Mokoena        M    70.0
# 15                Aaron Mooy        M    61.0
# 16              Aaron Ramsey        M    77.0
# 17           Aaron Wilbraham        A    61.0
# 18             Aarón Galindo        D    69.0
# 19             Aarón Padilla        A    61.0
# 20         Aatif Chahechouhe        M    56.0
# 21    Abdelhamid El Kaoutari        D    72.0
# 22        Abdelkader Ghezzal        A    73.0
# 23         Abderrazzak Jadid        M    66.0
# 24         Abdisalam Ibrahim        M    65.0
# 25       Abdou Razack Traoré        A    75.0
# 26              Abdou Traoré        M    67.0
# 27         Abdoul Karim Yoda        M    66.0
# 28    Abdoul Razzagui Camara        A    69.0
# 29            Abdoulay Konko        D    76.0
# ...                      ...      ...     ...
# 8764                 Éverton        M    69.0
# 8765                   Índio        M    68.0
# 8766        Ívar Ingimarsson        D    67.0
# 8767             Íñigo Vélez        A    63.0
# 8768         Ólafur Skúlason        M    63.0
# 8769                   Óscar        M    71.0
# 8770           Óscar Cardozo        A    81.0
# 8771             Óscar Pérez       GK    68.0
# 8772             Óscar Rojas        D    69.0
# 8773           Óscar Sánchez        D    61.0
# 8774             Óscar Trejo        A    74.0
# 8775             Ömer Bayram        A    59.0
# 8776             Ömer Toprak        D    74.0
# 8777          Özkan Yildirim        M    62.0
# 8778         Øyvind Storflor        A    66.0
# 8779            Ümit Korkmaz        M    71.0
# 8780          Łukasz Burliga        D    59.0
# 8781        Łukasz Fabiański       GK    77.0
# 8782          Łukasz Garguła        M    68.0
# 8783           Łukasz Hanzel        M    59.0
# 8784         Łukasz Janoszka        M    58.0
# 8785            Łukasz Madej        M    64.0
# 8786         Łukasz Piszczek        D    76.0
# 8787           Łukasz Sapela       GK    63.0
# 8788            Łukasz Surma        M    60.0
# 8789           Łukasz Trałka        M    67.0
# 8790         Łukasz Tymiński        M    54.0
# 8791          Łukasz Załuska       GK    69.0
# 8792               Šaćir Hot        D    57.0
# 8793         Žarco Tomašević        D    68.0
#
# [8794 rows x 3 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-eb5413fac020> in <module>()
#       1 #Group By Location and Time
# ----> 2 df_loc_time = df.groupby(['Location Category', 'Time'])['Killed', 'Injured'].sum()
#       3 #Reset Index
#       4 df_loc_time.reset_index(level=[0, 1], inplace=True)
#
# NameError: name 'df' is not defined

# %%
#Group By Location and Time
df_loc_time = df.groupby(['Location Category', 'Time'])['Killed', 'Injured'].sum()
#Reset Index
df_loc_time.reset_index(level=[0, 1], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-eb5413fac020> in <module>()
#       1 #Group By Location and Time
# ----> 2 df_loc_time = df.groupby(['Location Category', 'Time'])['Killed', 'Injured'].sum()
#       3 #Reset Index
#       4 df_loc_time.reset_index(level=[0, 1], inplace=True)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6657         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6658                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6659                        observed=observed, **kwargs)
#    6660
#    6661     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, **kwargs)
#     597                                                     sort=sort,
#     598                                                     observed=observed,
# --> 599                                                     mutated=self.mutated)
#     600
#     601         self.obj = obj
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/groupby/groupby.py in _get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#    3289                 in_axis, name, level, gpr = False, None, gpr, None
#    3290             else:
# -> 3291                 raise KeyError(gpr)
#    3292         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    3293             # Add key to exclusions
#
# KeyError: 'Location Category'
