# %% [markdown]
# # Day 002
#
# ## Learn Python for Data Science: The Basics
#
# - [Python Lists][1]
# - [List Comprehensions][2]
# - [Python Tuples][3]
# - [Python Dictionaries and Dictionary Comprehensions][4]
# - [Decision Making in Python][5]
# - [Loops in Python][6]
#
#
# ## Tools
#
# - **Visualizations**
# 	- [MicroStrategy][7]
# 	- [Tableau][8]
# 	- [Power BI][9]
# 	- [D3.js Open Source JS Lib][10]
#
# - **Machine Learning**
# 	- [KNIME][11]
# 	- [Weka][12]
# 	- [Orange][13]
# 	- [SAS Enterprise Miner (Tele, )][14]
# 	- [IBM SPSS Modeler (Banks, Ufone)][15]
# 	- [SAP Infinite Insight (Mobilink) ][16]
#
# ## Misc
#
# - **Readings**
# 	- [Analytics Vidhya][17]
# 	- [Data Science Central][18]
# 	- [KDD][19]
#
# - **Certifications and Datasets**
#
# 	- [Cognitive AI for Certifications][20]
# 	- [Kaggle][21]
#
#
# [1]: https://data-flair.training/blogs/python-lists-examples/
# [2]: https://data-flair.training/blogs/python-list-comprehension/
# [3]: https://data-flair.training/blogs/python-tuples-syntax-examples/
# [4]: https://data-flair.training/blogs/python-dictionary/
# [5]: https://data-flair.training/blogs/python-decision-making-expressions/
# [6]: https://data-flair.training/blogs/python-loops/
# [7]: https://www.microstrategy.com/us
# [8]: https://public.tableau.com/en-us/s/
# [9]: https://powerbi.microsoft.com/en-us/
# [10]: https://d3js.org/
# [11]: https://www.knime.com/
# [12]: https://www.cs.waikato.ac.nz/ml/weka/
# [13]: https://orange.biolab.si/
# [14]: https://www.sas.com/en_us/software/enterprise-miner.html
# [15]: https://www.ibm.com/products/spss-modeler
# [16]: https://blogs.sap.com/2014/02/13/predictive-analytics-sap-infinite-insights/
# [17]: https://www.analyticsvidhya.com/
# [18]: https://www.datasciencecentral.com/
# [19]: http://www.kdd.org/
# [20]: https://cognitiveclass.ai/
# [21]: https://www.kaggle.com/muhammadtaqi
# [22]: https://www.kaggle.com/muhammadtaqi
# [23]: https://www.kaggle.com/muhammadtaqi
