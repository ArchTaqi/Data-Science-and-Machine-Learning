# %% [markdown]
# # Day 19

# %% [markdown]
# **Probability Trees**
#
# What is prob that car is efficient and given that it is petrol ?
#
# P (E|P) = P(E&P) / P(P)
# P(E|P) = (35/100) / (38/100)
#
#
#
# What is the prob that car is efficient and givent that it is deisel?
# P(E|D) = P(E&D) / P(D)
#
#           = (25/100) / (25+37)
#           =
#
# Conditional Prob. = A & B
# Joint Porb. =
# Marginal Prob. =
#
#
# what is the prob that a Person has Master degree and earns 1lakh plus?
#
#
# total = 12k, masters = 6k

# %% [markdown]
# # Machine Learning

# %% [markdown]
# **Abiliyt to learn without being explicitly programmed.**
#
# - Un-supervised , pattern finding,
# - supervised, jdhr prediction krni hoti hai.
# - Reinforcement,
#
#
# - Data, Problem, Validation
#
# predict who will churn?
#
#
# - **Supervised**
#
#     - input object (explanatory variables) X [location, min, data]   Questions
#     - desired output value (response variable). Y [isChurn]           Answers
#
#     - Classification, for categorical variable ki prediction
#     - Regression, Numerical variables ki prediction
#
#     Both X and Y are given.
#     Hm question answers phle data ki form me provide krty hain, jis pr machine ko train krty hain.
#
#
# - **Unsupervised**
#     - for descriptive analysis
#
#     X variables given hoty hain, Y predict krna hota hai.
#
# 4Ps, Product, Price, Place, Promotions
# MBAs (Markeet Basket analysis), ek time pr ek customer kia kai cheez krheed rahai hai.
#
# Retail analytics, Event analytics
# Error analytics (ek error aa hai to kai prob hai k sath ye error b aya ho ga) or (ek errro aya hai to 2nd error kb aye ga)
#
#
#
#
#     - Associations,  Ek event occur huw hai, ktni prob hai k 2nd event b usi k sath huwa ho ga., if we talk about future k kb ho ga, then it's called prediction. if in the same time then it's associations
#     - Cluster , in business terms it's called segmentations.
#
#
# Pop alo, Apripri
#
#
# if A is diper and B is Bear, then it's said if customer buy's A then he will buy B.
#
# Support(A) means Porb of A P(A) = count of A / totals
#
# **Support (A===>B)** = P(A&B) /N
#                                      = P(A&B)
#
# reasonable support ( P A&B) any chahye, agr bht minimum hai to ignore krain.
#
# i.e P(A) = 10% , P(B)=12% , P(A&B) = 1%, now P(A&B) is meaning less to us and no benifit of doing futher analysis.
#
#
# if P(A) = 0.5 and P(A|B) = 0.8, then it's +ve corrlations
# if P(A) = 0.5 and P(A|B) = 0.3, then it's -ve correleations.
#
#
# **Lift(A====>B)** = P(A&B) / P(A) * P(B) or Confidence(A==>B) / P(B)
# lift > 1 , P(A&B) is greater, +ve correlation
# lift < 1, -ve correlations.
# lift = 1, independent
#
# P(A&B) means both are dependent
# P(A) * P(B) means both are independent
# - Naive model
#
#
# **leverage** = P(A&B) - P(A) * P(B)
#
# if 0 , koi impact ni
# if -ve , -ve impact
# if +ve, +ve impact
#
# Jb A ya B me se kisi ek ki support bht zada hai to phr outcome wrong aa skti ahi. i.e 9/0.1 = 90, it's also called Class InBalance.
#
# To remove Inbalancy we used Leverage  9-0.1 = 8.9
#
#
# **What is the difference between lift and leverage?**
#
# Both lift and leverage measure the relation between the probability of a given rule to occur (support(A→C)) and its expected probability if the items were independent (coverage(A)*coverage(C)) of each other. The only difference is that lift computes the ratio of both factors (support(A→C)/(coverage(A)*coverage(C))) and leverage computes the difference (support(A→C)-(coverage(A)*coverage(C))). The implications are that lift may find very strong associations for less frequent items, while leverage tends to prioritize items with higher frequencies/support in the dataset.
#
#
# What is the prob that A and B will not occur at once time.
# **Conviction (A===>B)** =  1-support(B) / 1-confidence(a==>b)
#                                 =  1 - no of b occures / 1 - chances of B given A
#                                 = Prob that B doesn't occurss / Porb that B  does not occures when A has occured.
#
#
# Conviction value zada hai to means it's comming by chance.
#
# Lift value zada honi chahy, conviction ki km hone chahye
#
# https://www.quora.com/What-is-a-good-threshold-in-association-rule-mining-for-support-and-confidence-in-order-to-have-reliable-rules

# %% [markdown]
# B & C ==> D (B and C to lia hai , sth me D b le ga?)
#
# confidence (B&C==>D) = P(B&C ==>D) / P(B&C)
# lift(B&C==>D) = conf(B&C==>D) / P(D)
#
#
#
# Ranges
#
# - support [0,1]
# - confidence [0,1]
# - lift [0 , infinity]        ,if value > 1 then +ve impact
# - leverage [-1,1]
# - conv[0,infinity]       , if value > 1, then it's more importance.
