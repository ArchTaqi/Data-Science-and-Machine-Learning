# %% [markdown]
# **Probability Basics**
#
# - disjoint event, ek time pr ek event hoga ya head ya tail.
#
# P(A) = probability of A
# P(H) = porbabiliyt of Head, 1/2
#
#
# 2 values k btw agr finite values hain to **Discreate** hai i.e hockey goals 3 5, 3 and 5 k btw bs ek value hai 4
# 2 values k btw agr infinite values hain to **continoues** hai. i.e height of plyaers 4.5 , 6.8  (4.5 se 6.8 k btw bht values hain i.e 5.00005, 5.004 etc)
#
# **Frequentist interpretation** -
#
#
# **Law of large numbers** - jnte zada events honge, unti probabiliy increase ho jai gi.
#
# **PMF**, pobabiliy mass functions for discreate variables
# tells the frequency of each event of probabilty
#
# H --> 38/100 = 38%
# T --> 62/100 = 62%
#
# **PDF** for contiyoues variables, table ni bnta, bcz we can't count.
# isko convert kr skty hain discreate me, i.e 2 to 6 inches ko bins md divide kr dain , now we have some range, so it's close to discreate.
#
#
# **CDF** commulative distribution functions, for both discreate and continuoues.
#
#
#
#
# discreate numbers ki easily prob bn jati hai, i.e Historgram of temp bines [35, 37, 39, 41, 43 ]
# continioues numbers ki prb mushkil hai, i.e Historgram of temp bins [35.1111, 35.03, 35.0007 ], bht distrub count prob bny gi.
# continuoues data ki bins hm range or interval me bnaty hain.
# i.e sea pond fish catching example by pin and jaal.
#
# **PDV vs CDF**
#
#
#
# **Disjoint vs Non-Disjoint Events**
#
# - Disjoint No intersaction       P(A) + P(B)
# - Non-disjoing , intersaction       P(A) + P(B) - P(A and B)
#
# what is prob that customers will stay in network and give revenue more than 300? dis-joint event
#
#
# **Sample space** - you know all possible outcomes [ either head or tail], but i don't know which one will occur when.
#
# **Probability Distribution** -
#
# **Complimentary events** -
#
#
# - **every complimentary events are dis-joint events.**
# - **all dis-joints events are not complimentary **
#
#
# **Independent Process** ek event 2nd event ki prob ko effect krta hai k nahi?
#
# **Product Rule** if events are independent then the whole porb is multiple of each.
#
# **Disjoint vs Independance**
#
#
#
# **Study** contigency table, of 2 different categorical variables. prob calculated from margins of contigency table margins is callled Marginal Probability whereas Joint Probability is calculated from joints of contigency table.
#
# Conditional Probability is when one porb of tow event is given and we have to find the other one.
#
# ```
# P( H | T ) = 0.5                          it means that both are independent.
# ```
#
#
# when dependent then there is correlations.
#
# **Bayes’ Theorem** = Joint prob / marginal porb
#
# **General product rule**, when we don't know wheather event is dependent or independent.
#
# **Probability Trees**
#
#
# **What? Why? What will happened? ---?**
