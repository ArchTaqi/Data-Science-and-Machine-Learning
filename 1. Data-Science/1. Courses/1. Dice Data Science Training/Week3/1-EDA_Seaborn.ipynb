# %% [markdown]
# # EDA

# %% [markdown]
# ## 1. Loading Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# use matplotlib in seaborn
# %matplotlib inline

# %% [markdown]
# ## 2. Loading Data & Basic Analysis

# %%
data = pd.read_csv('train.csv')
df = data.copy()

# %% [markdown]
# ### Basic Structure

# %%
df.shape
# Out:
# (891, 12)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include=["O"])
# Out:
#                       Name   Sex    Ticket    Cabin Embarked
# count                  891   891       891      204      889
# unique                 891     2       681      147        3
# top     Hassab, Mr. Hammad  male  CA. 2343  B96 B98        S
# freq                     1   577         7        4      644

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                Name   Sex  \
# count    891.000000  891.000000  891.000000                 891   891
# unique          NaN         NaN         NaN                 891     2
# top             NaN         NaN         NaN  Hassab, Mr. Hammad  male
# freq            NaN         NaN         NaN                   1   577
# mean     446.000000    0.383838    2.308642                 NaN   NaN
# std      257.353842    0.486592    0.836071                 NaN   NaN
# min        1.000000    0.000000    1.000000                 NaN   NaN
# 25%      223.500000    0.000000    2.000000                 NaN   NaN
# 50%      446.000000    0.000000    3.000000                 NaN   NaN
# 75%      668.500000    1.000000    3.000000                 NaN   NaN
# max      891.000000    1.000000    3.000000                 NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000       891  891.000000      204
# unique         NaN         NaN         NaN       681         NaN      147
# top            NaN         NaN         NaN  CA. 2343         NaN  B96 B98
# freq           NaN         NaN         NaN         7         NaN        4
# mean     29.699118    0.523008    0.381594       NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057       NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000       NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000       NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000       NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000       NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000       NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %% [markdown]
# ### Completeness

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## 3. Exploration

# %% [markdown]
# ### 3.1 Exploration of Complete & Important Variables
#
# Our response variable in the training set is complete, as well as Sex and Pclass, which seem two of the most important predictors.

# %% [markdown]
# **Survival**

# %%
sns.countplot(x='Survived', hue='Survived', data=df);

# %% [markdown]
# **Gender & Survival**

# %%
sns.countplot(x='Sex', data=df);

# %%
sns.countplot(x='Sex', hue='Survived', data=df);

# %% [markdown]
# **Passenger Class & Survival**

# %%
sns.countplot(x='Pclass', data=df);

# %%
sns.countplot(x='Pclass', hue='Survived', data=df);

# %% [markdown]
# **Passenger Class, Gender & Survival**

# %%
sns.factorplot(x='Sex', col='Pclass', data=df, kind='count');

# %%
# factor plot rows bnata hai and un rows me columns
sns.factorplot(x='Sex', col='Pclass', hue='Survived', data=df, kind='count');

# %% [markdown]
# ### 3.2 What's in the name?

# %%
df['Name'].head(10)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %% [markdown]
# **Extracting & Analyzing Titles**

# %%
import re
df['Title'] = df['Name'].apply(lambda x: re.search(' ([A-Z][a-z]+)\.', x).group(1))
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title
# 0      0         A/5 21171   7.2500   NaN        S    Mr
# 1      0          PC 17599  71.2833   C85        C   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3      0            113803  53.1000  C123        S   Mrs
# 4      0            373450   8.0500   NaN        S    Mr

# %%
df['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Col           2
# Mlle          2
# Major         2
# Jonkheer      1
# Don           1
# Mme           1
# Sir           1
# Capt          1
# Lady          1
# Countess      1
# Ms            1
# Name: Title, dtype: int64

# %% [markdown]
# ___Dividing Titles into bigger categories___

# %% [markdown]
# The term *Mademoiselle* is a French familiar title, abbreviated **Mlle**, traditionally given to an unmarried woman. The equivalent in English is "Miss". However, the courtesy title "Madame" is accorded women where their marital status is unknown.

# %%
df['Title'] = df['Title'].replace('Mlle', 'Miss')

# %% [markdown]
# In France, one traditionally calls a young, unmarried woman Mademoiselle – Mlle for short – and an older, married woman _Madame_, whose abbreviation is **Mme**.

# %%
df['Title'] = df['Title'].replace('Mme', 'Mrs')

# %%
i = df[~df['Title'].isin(['Mr', 'Mrs', 'Miss', 'Master'])].index
df.loc[i, 'Title'] = 'Rare Title'

# %%
df['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Rare Title'], dtype=object)

# %%
sns.countplot(data=df,x='Title', hue='Survived');

# %% [markdown]
# ### 3.3 Travelling Alone vs. Travelling in groups

# %% [markdown]
# **3.3.1 Family Size**

# %%
df['Fsize'] = df['SibSp'] + df['Parch']+1

# %%
sns.countplot(x='Fsize', hue='Survived', data=df);

# %%
temp = df.groupby('Fsize')['Survived'].value_counts(normalize=True).reset_index(name='Perc')

plt.figure(figsize=(15,6));

plt.subplot(121)
sns.barplot(data=temp,x='Fsize', y='Perc', hue='Survived', dodge=True);

plt.subplot(122)
sns.barplot(data=temp,x='Fsize', y='Perc', hue='Survived', dodge=False);

# %% [markdown]
# **3.3.2 How many people booked together?**
#
# _Apart from families, there could be groups of friends travelling together._

# %%
df['Ticket'].value_counts().reset_index(name='Tsize')
# Out:
#                   index  Tsize
# 0              CA. 2343      7
# 1                  1601      7
# 2                347082      7
# 3               CA 2144      6
# 4                347088      6
# 5               3101295      6
# 6          S.O.C. 14879      5
# 7                382652      5
# 8                  2666      4
# 9                 17421      4
# 10               113760      4
# 11                19950      4
# 12           W./C. 6608      4
# 13                 LINE      4
# 14               113781      4
# 15                 4133      4
# 16               349909      4
# 17             PC 17757      4
# 18               347077      4
# 19             PC 17755      3
# 20           C.A. 31921      3
# 21               248727      3
# 22               110413      3
# 23         F.C.C. 13529      3
# 24                24160      3
# 25             PC 17572      3
# 26                29106      3
# 27                13502      3
# 28                35273      3
# 29               230080      3
# ..                  ...    ...
# 651              349245      1
# 652               19947      1
# 653          C.A. 33111      1
# 654   STON/O 2. 3101294      1
# 655              237789      1
# 656           A/5 21174      1
# 657              113800      1
# 658              220367      1
# 659              349210      1
# 660          W./C. 6609      1
# 661              218629      1
# 662               36866      1
# 663              112277      1
# 664   STON/O 2. 3101280      1
# 665  SOTON/O.Q. 3101307      1
# 666    STON/O2. 3101283      1
# 667    STON/O2. 3101271      1
# 668          SO/C 14885      1
# 669                4136      1
# 670               28551      1
# 671               28425      1
# 672              248706      1
# 673            A/5 2817      1
# 674              349228      1
# 675              374887      1
# 676              315153      1
# 677            PC 17610      1
# 678              112379      1
# 679                2647      1
# 680               13509      1
#
# [681 rows x 2 columns]

# %%
temp = df['Ticket'].value_counts().reset_index(name='Tsize')
df = df.merge(temp, left_on='Ticket', right_on='index',how='inner').drop('index', axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4          138         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                        Futrelle, Mr. Jacques Heath    male  37.0      1
#
#    Parch            Ticket     Fare Cabin Embarked Title  Fsize  Tsize
# 0      0         A/5 21171   7.2500   NaN        S    Mr      2      1
# 1      0          PC 17599  71.2833   C85        C   Mrs      2      1
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss      1      1
# 3      0            113803  53.1000  C123        S   Mrs      2      2
# 4      0            113803  53.1000  C123        S    Mr      2      2

# %%
sns.countplot(x='Tsize', hue='Survived', data=df);

# %%
temp = df.groupby('Tsize')['Survived'].value_counts(normalize=True).reset_index(name='Perc')

sns.barplot(x='Tsize', y='Perc', hue='Survived', data=temp, dodge=True);

# %% [markdown]
# **3.3.3 Consolidating family & friends**

# %%
df['Group'] = df[['Tsize', 'Fsize']].max(axis=1)

# %%
sns.countplot(x='Group', hue='Survived', data=df);

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4          138         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                        Futrelle, Mr. Jacques Heath    male  37.0      1
#
#    Parch            Ticket     Fare Cabin Embarked Title  Fsize  Tsize  Group
# 0      0         A/5 21171   7.2500   NaN        S    Mr      2      1      2
# 1      0          PC 17599  71.2833   C85        C   Mrs      2      1      2
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss      1      1      1
# 3      0            113803  53.1000  C123        S   Mrs      2      2      2
# 4      0            113803  53.1000  C123        S    Mr      2      2      2

# %%
df['GrpSize'] = ''
df.loc[df['Group']==1, 'GrpSize'] = df.loc[df['Group']==1, 'GrpSize'].replace('', 'solo')
df.loc[df['Group']==2, 'GrpSize'] = df.loc[df['Group']==2, 'GrpSize'].replace('', 'couple')
df.loc[(df['Group']<=4) & (df['Group']>=3), 'GrpSize'] = df.loc[(df['Group']<=4) & (df['Group']>=3), 'GrpSize'].replace('', 'group')
df.loc[df['Group']>4, 'GrpSize'] = df.loc[df['Group']>4, 'GrpSize'].replace('', 'large group')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4            138         0       1
# 5              5         0       3
# 6              6         0       3
# 7              7         0       1
# 8              8         0       3
# 9             25         0       3
# 10           375         0       3
# 11           568         0       3
# 12             9         1       3
# 13           173         1       3
# 14           870         1       3
# 15            10         1       2
# 16           123         0       2
# 17            11         1       3
# 18           395         1       3
# 19            12         1       1
# 20            13         0       3
# 21            14         0       3
# 22           120         0       3
# 23           542         0       3
# 24           543         0       3
# 25           611         0       3
# 26           814         0       3
# 27           851         0       3
# 28            15         0       3
# 29            16         1       2
# ..           ...       ...     ...
# 861          845         0       3
# 862          846         0       3
# 863          848         0       3
# 864          852         0       3
# 865          854         1       1
# 866          856         1       3
# 867          858         1       1
# 868          860         0       3
# 869          861         0       3
# 870          862         0       2
# 871          863         1       1
# 872          865         0       2
# 873          866         1       2
# 874          867         1       2
# 875          868         0       1
# 876          869         0       3
# 877          871         0       3
# 878          873         0       1
# 879          874         0       3
# 880          876         1       3
# 881          878         0       3
# 882          879         0       3
# 883          882         0       3
# 884          883         0       3
# 885          884         0       2
# 886          885         0       3
# 887          887         0       2
# 888          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                          Futrelle, Mr. Jacques Heath    male  37.0      1
# 5                             Allen, Mr. William Henry    male  35.0      0
# 6                                     Moran, Mr. James    male   NaN      0
# 7                              McCarthy, Mr. Timothy J    male  54.0      0
# 8                       Palsson, Master. Gosta Leonard    male   2.0      3
# 9                        Palsson, Miss. Torborg Danira  female   8.0      3
# 10                          Palsson, Miss. Stina Viola  female   3.0      3
# 11         Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 12   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 13                        Johnson, Miss. Eleanor Ileen  female   1.0      1
# 14                     Johnson, Master. Harold Theodor    male   4.0      1
# 15                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 16                                Nasser, Mr. Nicholas    male  32.5      1
# 17                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 18   Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...  female  24.0      0
# 19                            Bonnell, Miss. Elizabeth  female  58.0      0
# 20                      Saundercock, Mr. William Henry    male  20.0      0
# 21                         Andersson, Mr. Anders Johan    male  39.0      1
# 22                   Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 23                Andersson, Miss. Ingeborg Constanzia  female   9.0      4
# 24                   Andersson, Miss. Sigrid Elisabeth  female  11.0      4
# 25   Andersson, Mrs. Anders Johan (Alfrida Konstant...  female  39.0      1
# 26                  Andersson, Miss. Ebba Iris Alfrida  female   6.0      4
# 27             Andersson, Master. Sigvard Harald Elias    male   4.0      4
# 28                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 29                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# 861                                Culumovic, Mr. Jeso    male  17.0      0
# 862                                Abbing, Mr. Anthony    male  42.0      0
# 863                                 Markoff, Mr. Marin    male  35.0      0
# 864                                Svensson, Mr. Johan    male  74.0      0
# 865                          Lines, Miss. Mary Conover  female  16.0      0
# 866                         Aks, Mrs. Sam (Leah Rosen)  female  18.0      0
# 867                             Daly, Mr. Peter Denis     male  51.0      0
# 868                                   Razi, Mr. Raihed    male   NaN      0
# 869                            Hansen, Mr. Claus Peter    male  41.0      2
# 870                        Giles, Mr. Frederick Edward    male  21.0      1
# 871  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 872                             Gill, Mr. John William    male  24.0      0
# 873                           Bystrom, Mrs. (Karolina)  female  42.0      0
# 874                       Duran y More, Miss. Asuncion  female  27.0      1
# 875               Roebling, Mr. Washington Augustus II    male  31.0      0
# 876                        van Melkebeke, Mr. Philemon    male   NaN      0
# 877                                  Balkic, Mr. Cerin    male  26.0      0
# 878                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 880                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 881                               Petroff, Mr. Nedelio    male  19.0      0
# 882                                 Laleff, Mr. Kristo    male   NaN      0
# 883                                 Markun, Mr. Johann    male  33.0      0
# 884                       Dahlberg, Miss. Gerda Ulrika  female  22.0      0
# 885                      Banfield, Mr. Frederick James    male  28.0      0
# 886                             Sutehall, Mr. Henry Jr    male  25.0      0
# 887                              Montvila, Rev. Juozas    male  27.0      0
# 888                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare        Cabin Embarked       Title  \
# 0        0         A/5 21171   7.2500          NaN        S          Mr
# 1        0          PC 17599  71.2833          C85        C         Mrs
# 2        0  STON/O2. 3101282   7.9250          NaN        S        Miss
# 3        0            113803  53.1000         C123        S         Mrs
# 4        0            113803  53.1000         C123        S          Mr
# 5        0            373450   8.0500          NaN        S          Mr
# 6        0            330877   8.4583          NaN        Q          Mr
# 7        0             17463  51.8625          E46        S          Mr
# 8        1            349909  21.0750          NaN        S      Master
# 9        1            349909  21.0750          NaN        S        Miss
# 10       1            349909  21.0750          NaN        S        Miss
# 11       4            349909  21.0750          NaN        S         Mrs
# 12       2            347742  11.1333          NaN        S         Mrs
# 13       1            347742  11.1333          NaN        S        Miss
# 14       1            347742  11.1333          NaN        S      Master
# 15       0            237736  30.0708          NaN        C         Mrs
# 16       0            237736  30.0708          NaN        C          Mr
# 17       1           PP 9549  16.7000           G6        S        Miss
# 18       2           PP 9549  16.7000           G6        S         Mrs
# 19       0            113783  26.5500         C103        S        Miss
# 20       0         A/5. 2151   8.0500          NaN        S          Mr
# 21       5            347082  31.2750          NaN        S          Mr
# 22       2            347082  31.2750          NaN        S        Miss
# 23       2            347082  31.2750          NaN        S        Miss
# 24       2            347082  31.2750          NaN        S        Miss
# 25       5            347082  31.2750          NaN        S         Mrs
# 26       2            347082  31.2750          NaN        S        Miss
# 27       2            347082  31.2750          NaN        S      Master
# 28       0            350406   7.8542          NaN        S        Miss
# 29       0            248706  16.0000          NaN        S         Mrs
# ..     ...               ...      ...          ...      ...         ...
# 861      0            315090   8.6625          NaN        S          Mr
# 862      0         C.A. 5547   7.5500          NaN        S          Mr
# 863      0            349213   7.8958          NaN        C          Mr
# 864      0            347060   7.7750          NaN        S          Mr
# 865      1          PC 17592  39.4000          D28        S        Miss
# 866      1            392091   9.3500          NaN        S         Mrs
# 867      0            113055  26.5500          E17        S          Mr
# 868      0              2629   7.2292          NaN        C          Mr
# 869      0            350026  14.1083          NaN        S          Mr
# 870      0             28134  11.5000          NaN        S          Mr
# 871      0             17466  25.9292          D17        S         Mrs
# 872      0            233866  13.0000          NaN        S          Mr
# 873      0            236852  13.0000          NaN        S         Mrs
# 874      0     SC/PARIS 2149  13.8583          NaN        C        Miss
# 875      0          PC 17590  50.4958          A24        S          Mr
# 876      0            345777   9.5000          NaN        S          Mr
# 877      0            349248   7.8958          NaN        S          Mr
# 878      0               695   5.0000  B51 B53 B55        S          Mr
# 879      0            345765   9.0000          NaN        S          Mr
# 880      0              2667   7.2250          NaN        C        Miss
# 881      0            349212   7.8958          NaN        S          Mr
# 882      0            349217   7.8958          NaN        S          Mr
# 883      0            349257   7.8958          NaN        S          Mr
# 884      0              7552  10.5167          NaN        S        Miss
# 885      0  C.A./SOTON 34068  10.5000          NaN        S          Mr
# 886      0   SOTON/OQ 392076   7.0500          NaN        S          Mr
# 887      0            211536  13.0000          NaN        S  Rare Title
# 888      0            112053  30.0000          B42        S        Miss
# 889      0            111369  30.0000         C148        C          Mr
# 890      0            370376   7.7500          NaN        Q          Mr
#
#      Fsize  Tsize  Group      GrpSize
# 0        2      1      2       couple
# 1        2      1      2       couple
# 2        1      1      1         solo
# 3        2      2      2       couple
# 4        2      2      2       couple
# 5        1      1      1         solo
# 6        1      1      1         solo
# 7        1      1      1         solo
# 8        5      4      5  large group
# 9        5      4      5  large group
# 10       5      4      5  large group
# 11       5      4      5  large group
# 12       3      3      3        group
# 13       3      3      3        group
# 14       3      3      3        group
# 15       2      2      2       couple
# 16       2      2      2       couple
# 17       3      2      3        group
# 18       3      2      3        group
# 19       1      1      1         solo
# 20       1      1      1         solo
# 21       7      7      7  large group
# 22       7      7      7  large group
# 23       7      7      7  large group
# 24       7      7      7  large group
# 25       7      7      7  large group
# 26       7      7      7  large group
# 27       7      7      7  large group
# 28       1      1      1         solo
# 29       1      1      1         solo
# ..     ...    ...    ...          ...
# 861      1      1      1         solo
# 862      1      1      1         solo
# 863      1      1      1         solo
# 864      1      1      1         solo
# 865      2      1      2       couple
# 866      2      1      2       couple
# 867      1      1      1         solo
# 868      1      1      1         solo
# 869      3      1      3        group
# 870      2      1      2       couple
# 871      1      1      1         solo
# 872      1      1      1         solo
# 873      1      1      1         solo
# 874      2      1      2       couple
# 875      1      1      1         solo
# 876      1      1      1         solo
# 877      1      1      1         solo
# 878      1      1      1         solo
# 879      1      1      1         solo
# 880      1      1      1         solo
# 881      1      1      1         solo
# 882      1      1      1         solo
# 883      1      1      1         solo
# 884      1      1      1         solo
# 885      1      1      1         solo
# 886      1      1      1         solo
# 887      1      1      1         solo
# 888      1      1      1         solo
# 889      1      1      1         solo
# 890      1      1      1         solo
#
# [891 rows x 17 columns]

# %%
sns.countplot(x='GrpSize', order=['solo', 'couple', 'group', 'large group'], hue='Survived', data=df);

# %% [markdown]
# ### 3.4 Effect of Fare

# %%
df['Fare'].isnull().sum()
# Out:
# 0

# %%
plt.subplots(figsize=(15,6))
sns.distplot(df['Fare']);
# Out:
# /home/muhammadtaqi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df['Fare'].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
#          9.8458,  79.2   ,   6.75  ,  11.5   ,  36.75  ,   7.7958,
#         12.525 ,  66.6   ,   7.3125,  61.3792,   7.7333,  69.55  ,
#         16.1   ,  15.75  ,  20.525 ,  55.    ,  25.925 ,  33.5   ,
#         30.6958,  25.4667,  28.7125,   0.    ,  15.05  ,  39.    ,
#         22.025 ,  50.    ,   8.4042,   6.4958,  10.4625,  18.7875,
#         31.    , 113.275 ,  27.    ,  76.2917,  90.    ,   9.35  ,
#         13.5   ,   7.55  ,  26.25  ,  12.275 ,   7.125 ,  52.5542,
#         20.2125,  86.5   , 512.3292,  79.65  , 153.4625, 135.6333,
#         19.5   ,  29.7   ,  77.9583,  20.25  ,  78.85  ,  91.0792,
#         12.875 ,   8.85  , 151.55  ,  30.5   ,  23.25  ,  12.35  ,
#        110.8833, 108.9   ,  24.    ,  56.9292,  83.1583, 262.375 ,
#         14.    , 164.8667, 134.5   ,   6.2375,  57.9792,  28.5   ,
#        133.65  ,  15.9   ,   9.225 ,  35.    ,  75.25  ,  69.3   ,
#         55.4417, 211.5   ,   4.0125, 227.525 ,  15.7417,   7.7292,
#         12.    , 120.    ,  12.65  ,  18.75  ,   6.8583,  32.5   ,
#          7.875 ,  14.4   ,  55.9   ,   8.1125,  81.8583,  19.2583,
#         19.9667,  89.1042,  38.5   ,   7.725 ,  13.7917,   9.8375,
#          7.0458,   7.5208,  12.2875,   9.5875,  49.5042,  78.2667,
#         15.1   ,   7.6292,  22.525 ,  26.2875,  59.4   ,   7.4958,
#         34.0208,  93.5   , 221.7792, 106.425 ,  49.5   ,  71.    ,
#         13.8625,   7.8292,  39.6   ,  17.4   ,  51.4792,  26.3875,
#         30.    ,  40.125 ,   8.7125,  15.    ,  33.    ,  42.4   ,
#         15.55  ,  65.    ,  32.3208,   7.0542,   8.4333,  25.5875,
#          9.8417,   8.1375,  10.1708, 211.3375,  57.    ,  13.4167,
#          7.7417,   9.4833,   7.7375,   8.3625,  23.45  ,  25.9292,
#          8.6833,   8.5167,   7.8875,  37.0042,   6.45  ,   6.95  ,
#          8.3   ,   6.4375,  39.4   ,  14.1083,  13.8583,  50.4958,
#          5.    ,  10.5167])

# %%
df[df['Fare'] < 0]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Title, Fsize, Tsize, Group, GrpSize]
# Index: []

# %%
df[df['Fare'] == 0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 266          180         0       3               Leonard, Mr. Lionel  male
# 267          272         1       3      Tornquist, Mr. William Henry  male
# 268          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 269          598         0       3               Johnson, Mr. Alfred  male
# 366          264         0       1             Harrison, Mr. William  male
# 386          278         0       2       Parkes, Mr. Francis "Frank"  male
# 387          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 388          467         0       2             Campbell, Mr. William  male
# 592          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 715          634         0       1     Parr, Mr. William Henry Marsh  male
# 743          675         0       2        Watson, Mr. Ennis Hastings  male
# 786          733         0       2              Knight, Mr. Robert J  male
# 837          807         0       1            Andrews, Mr. Thomas Jr  male
# 843          816         0       1                  Fry, Mr. Richard  male
# 849          823         0       1   Reuchlin, Jonkheer. John George  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked       Title  Fsize  \
# 266  36.0      0      0    LINE   0.0   NaN        S          Mr      1
# 267  25.0      0      0    LINE   0.0   NaN        S          Mr      1
# 268  19.0      0      0    LINE   0.0   NaN        S          Mr      1
# 269  49.0      0      0    LINE   0.0   NaN        S          Mr      1
# 366  40.0      0      0  112059   0.0   B94        S          Mr      1
# 386   NaN      0      0  239853   0.0   NaN        S          Mr      1
# 387   NaN      0      0  239853   0.0   NaN        S          Mr      1
# 388   NaN      0      0  239853   0.0   NaN        S          Mr      1
# 592   NaN      0      0  239854   0.0   NaN        S          Mr      1
# 715   NaN      0      0  112052   0.0   NaN        S          Mr      1
# 743   NaN      0      0  239856   0.0   NaN        S          Mr      1
# 786   NaN      0      0  239855   0.0   NaN        S          Mr      1
# 837  39.0      0      0  112050   0.0   A36        S          Mr      1
# 843   NaN      0      0  112058   0.0  B102        S          Mr      1
# 849  38.0      0      0   19972   0.0   NaN        S  Rare Title      1
#
#      Tsize  Group GrpSize
# 266      4      4   group
# 267      4      4   group
# 268      4      4   group
# 269      4      4   group
# 366      1      1    solo
# 386      3      3   group
# 387      3      3   group
# 388      3      3   group
# 592      1      1    solo
# 715      1      1    solo
# 743      1      1    solo
# 786      1      1    solo
# 837      1      1    solo
# 843      1      1    solo
# 849      1      1    solo

# %%
df.loc[(df['Fare'] == 0) & (df['Pclass'] == 1), 'Fare'] = df[df['Pclass'] == 1]['Fare'].mean()
df.loc[(df['Fare'] == 0) & (df['Pclass'] == 2), 'Fare'] = df[df['Pclass'] == 2]['Fare'].mean()
df.loc[(df['Fare'] == 0) & (df['Pclass'] == 3), 'Fare'] = df[df['Pclass'] == 3]['Fare'].mean()

# %%
df['FareCat'] = ''
df.loc[df['Fare']<=10, 'FareCat'] = '0-10'
df.loc[(df['Fare']>10) & (df['Fare']<=25), 'FareCat'] = '10-25'
df.loc[(df['Fare']>25) & (df['Fare']<=40), 'FareCat'] = '25-40'
df.loc[(df['Fare']>40) & (df['Fare']<=70), 'FareCat'] = '40-70'
df.loc[(df['Fare']>70) & (df['Fare']<=100), 'FareCat'] = '70-100'
df.loc[df['Fare']>100, 'FareCat'] = '100+'
df[['Fare', 'FareCat']].head(10)
# Out:
#       Fare FareCat
# 0   7.2500    0-10
# 1  71.2833  70-100
# 2   7.9250    0-10
# 3  53.1000   40-70
# 4  53.1000   40-70
# 5   8.0500    0-10
# 6   8.4583    0-10
# 7  51.8625   40-70
# 8  21.0750   10-25
# 9  21.0750   10-25

# %%
df['Fare'].unique()
# Out:
# array([  7.25      ,  71.2833    ,   7.925     ,  53.1       ,
#          8.05      ,   8.4583    ,  51.8625    ,  21.075     ,
#         11.1333    ,  30.0708    ,  16.7       ,  26.55      ,
#         31.275     ,   7.8542    ,  16.        ,  29.125     ,
#         13.        ,  18.        ,   7.225     ,  26.        ,
#          8.0292    ,  35.5       ,  31.3875    , 263.        ,
#          7.8792    ,   7.8958    ,  27.7208    , 146.5208    ,
#          7.75      ,  10.5       ,  82.1708    ,  52.        ,
#          7.2292    ,  11.2417    ,   9.475     ,  21.        ,
#         41.5792    ,  15.5       ,  21.6792    ,  17.8       ,
#         39.6875    ,   7.8       ,  76.7292    ,  61.9792    ,
#         27.75      ,  46.9       ,  80.        ,  83.475     ,
#         27.9       ,  15.2458    ,   8.1583    ,   8.6625    ,
#         73.5       ,  14.4542    ,  56.4958    ,   7.65      ,
#         29.        ,  12.475     ,   9.        ,   9.5       ,
#          7.7875    ,  47.1       ,  15.85      ,  34.375     ,
#         61.175     ,  20.575     ,  34.6542    ,  63.3583    ,
#         23.        ,  77.2875    ,   8.6542    ,   7.775     ,
#         24.15      ,   9.825     ,  14.4583    , 247.5208    ,
#          7.1417    ,  22.3583    ,   6.975     ,   7.05      ,
#         14.5       ,  15.0458    ,  26.2833    ,   9.2167    ,
#          9.8458    ,  79.2       ,   6.75      ,  11.5       ,
#         36.75      ,   7.7958    ,  12.525     ,  66.6       ,
#          7.3125    ,  61.3792    ,   7.7333    ,  69.55      ,
#         16.1       ,  15.75      ,  20.525     ,  55.        ,
#         25.925     ,  33.5       ,  30.6958    ,  25.4667    ,
#         28.7125    ,  13.6755501 ,  15.05      ,  39.        ,
#         22.025     ,  50.        ,   8.4042    ,   6.4958    ,
#         10.4625    ,  18.7875    ,  31.        , 113.275     ,
#         27.        ,  76.2917    ,  90.        ,   9.35      ,
#         13.5       ,   7.55      ,  26.25      ,  12.275     ,
#          7.125     ,  52.5542    ,  20.2125    ,  86.5       ,
#        512.3292    ,  79.65      ,  84.1546875 , 153.4625    ,
#        135.6333    ,  19.5       ,  29.7       ,  77.9583    ,
#         20.66218315,  20.25      ,  78.85      ,  91.0792    ,
#         12.875     ,   8.85      , 151.55      ,  30.5       ,
#         23.25      ,  12.35      , 110.8833    , 108.9       ,
#         24.        ,  56.9292    ,  83.1583    , 262.375     ,
#         14.        , 164.8667    , 134.5       ,   6.2375    ,
#         57.9792    ,  28.5       , 133.65      ,  15.9       ,
#          9.225     ,  35.        ,  75.25      ,  69.3       ,
#         55.4417    , 211.5       ,   4.0125    , 227.525     ,
#         15.7417    ,   7.7292    ,  12.        , 120.        ,
#         12.65      ,  18.75      ,   6.8583    ,  32.5       ,
#          7.875     ,  14.4       ,  55.9       ,   8.1125    ,
#         81.8583    ,  19.2583    ,  19.9667    ,  89.1042    ,
#         38.5       ,   7.725     ,  13.7917    ,   9.8375    ,
#          7.0458    ,   7.5208    ,  12.2875    ,   9.5875    ,
#         49.5042    ,  78.2667    ,  15.1       ,   7.6292    ,
#         22.525     ,  26.2875    ,  59.4       ,   7.4958    ,
#         34.0208    ,  93.5       , 221.7792    , 106.425     ,
#         49.5       ,  71.        ,  13.8625    ,   7.8292    ,
#         39.6       ,  17.4       ,  51.4792    ,  26.3875    ,
#         30.        ,  40.125     ,   8.7125    ,  15.        ,
#         33.        ,  42.4       ,  15.55      ,  65.        ,
#         32.3208    ,   7.0542    ,   8.4333    ,  25.5875    ,
#          9.8417    ,   8.1375    ,  10.1708    , 211.3375    ,
#         57.        ,  13.4167    ,   7.7417    ,   9.4833    ,
#          7.7375    ,   8.3625    ,  23.45      ,  25.9292    ,
#          8.6833    ,   8.5167    ,   7.8875    ,  37.0042    ,
#          6.45      ,   6.95      ,   8.3       ,   6.4375    ,
#         39.4       ,  14.1083    ,  13.8583    ,  50.4958    ,
#          5.        ,  10.5167    ])

# %%
sns.countplot(x='FareCat', order=['0-10', '10-25', '25-40', '40-70', '70-100', '100+'], hue='Survived', data=df);

# %% [markdown]
# **Does ticket price correspond to group size?**

# %%
sns.lmplot(x='Group', y='Fare', data=df);

# %%
df['FarePP'] = df['Fare']/df['Group']

# %%
sns.distplot(df['FarePP'], kde=False);
# Out:
# /home/muhammadtaqi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df[df['FarePP']<=60]['FarePP'], kde=False);
# Out:
# /home/muhammadtaqi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### 3.5 Dropping Cabin?

# %%
sns.countplot(x='Cabin', hue='Survived', data=df);

# %%
df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'B80', 'D33', 'D49', 'B30', 'C52', 'B28',
#        'C83', 'F33', 'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110',
#        'A14', 'B58 B60', 'E101', 'F E69', 'D47', 'B86', 'B82 B84', 'F2',
#        'C2', 'E33', 'B19', 'A7', 'C49', 'F4', 'A32', 'B4', 'A31', 'D36',
#        'D48', 'D15', 'C93', 'C78', 'D35', 'C87', 'B77', 'B79',
#        'B51 B53 B55', 'B101', 'E67', 'E68', 'B94', 'C125', 'C91', 'C99',
#        'C32', 'C118', 'D7', 'D9', 'D11', 'A19', 'C46', 'B49', 'D',
#        'C22 C26', 'C106', 'C70', 'C68', 'C65', 'E36', 'A20', 'C54', 'C50',
#        'B57 B59 B63 B66', 'C7', 'E34', 'E40', 'B18', 'C124', 'T', 'C128',
#        'D37', 'B35', 'E50', 'C82', 'C62 C64', 'C45', 'B96 B98', 'E10',
#        'E44', 'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63',
#        'B37', 'C30', 'D20', 'E25', 'D46', 'B73', 'B69', 'C95', 'B38',
#        'C86', 'B39', 'B22', 'A16', 'C101', 'A10', 'B41', 'D19', 'D50',
#        'A23', 'B50', 'A26', 'E58', 'C126', 'B71', 'B5', 'B3', 'B20',
#        'F G63', 'E24', 'C90', 'E8', 'D45', 'D30', 'E121', 'E77', 'F38',
#        'D6', 'D17', 'A36', 'B102', 'E49', 'C47', 'D28', 'E17', 'A24',
#        'B42', 'C148'], dtype=object)

# %%
df['CabinType'] = df['Cabin'].str[0]
sns.countplot(x='CabinType', hue='Survived', data=df);

# %% [markdown]
# ### 3.6 Effect of Embarked variable
#
# _C = Cherbourg(France), Q = Queenstown(Ireland), S = Southampton(England)_

# %%
sns.countplot(x='Embarked', hue='Survived', data=df);

# %%
sns.barplot(x='Embarked', y='Age', hue='Survived', data=df);

# if our data has missing values then bar plot will show these black lines in between, it's also means that mean is 0.

# %%
temp = df.groupby('Embarked')['Survived'].value_counts(normalize=True).reset_index(name='Perc')

sns.barplot(x='Embarked', y='Perc', hue='Survived', data=temp, dodge=True);

# %% [markdown]
# ***Engineered Features***

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Title  Fsize  Tsize  Group  \
# 0      0  A/5 21171   7.2500   NaN        S    Mr      2      1      2
# 1      0   PC 17599  71.2833   C85        C   Mrs      2      1      2
#
#   GrpSize FareCat    FarePP CabinType
# 0  couple    0-10   3.62500       NaN
# 1  couple  70-100  35.64165         C

# %% [markdown]
# ## 4. Missing Values

# %% [markdown]
# ### 4.1 Age

# %%
sns.kdeplot(df[df['Survived'] == 0]['Age'].dropna());   # X's age, Y's % of survived bcs kdeplot me count ni hoti, percentage hoti hai.

# %%
sns.kdeplot(df[df['Survived'] == 0]['Age'].dropna(), shade=True);
sns.kdeplot(df[df['Survived'] == 1]['Age'].dropna(), shade=True);

# %%
temp = df[df['Age'].isnull() == False]               # create new df of data where age is null

# %%
sns.set_context('poster')
sns.factorplot(kind='box', x='Age', col='Title', row='Pclass', data=temp);

# %%
for t in df['Title'].unique():
    for p in df['Pclass'].unique():
        df.loc[(df['Title'] == t) & (df['Pclass'] == p) & (df['Age'].isnull()), 'Age'] = df.loc[(df['Title'] == t) & (df['Pclass'] == p), 'Age'].median()

# %%
df['Age'].hist();

# %%
sns.distplot(df['Age'], hist=False);

# %%
sns.kdeplot(df[df['Survived'] == 0]['Age'], shade=True);
sns.kdeplot(df[df['Survived'] == 1]['Age'], shade=True);

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
# pair plots columns into columns ka bna thai 2D of columns
sns.pairplot(df, hue='Survived', kind='scatter');

# %% [markdown]
# # Visualization
# ## Outline
#
# * Distribution of Data
#  * Univariate
#  * Bivariate
#  * Pairwise Bivariate
# * Plotting w/ Categorical data
#  * Categorical Scatterplots
#  * Category wise distribution of observations
#  * Category wise statistical estimation
#  * Multi-panel categorical plots

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

sns.set()
# %matplotlib inline

# %%
data = pd.read_csv('train.csv')
df = data.copy()
df['Title'] = df['Name'].apply(lambda x: re.search(' ([A-Z][a-z]+)\.', x).group(1))
mean_age = df['Age'].mean()
df['Age'] = df['Age'].fillna(mean_age)
df["Embarked"] = df["Embarked"].fillna('C')
print(data.shape)
df.head(2)
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Title
# 0      0  A/5 21171   7.2500   NaN        S    Mr
# 1      0   PC 17599  71.2833   C85        C   Mrs

# %% [markdown]
# ## Distribution of Data
#
# ### Univariate
#
# **Histogram & KDE (Kernel Density Estimate)**

# %%
sns.distplot(df['Age']);
# Out:
# /home/muhammadtaqi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df['Age'], kde=False);
# Out:
# /home/muhammadtaqi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df['Age'], hist=False);

# %% [markdown]
# The bandwidth (bw) parameter of the KDE controls how tightly the estimation is fit to the data, much like the bin size in a histogram. It corresponds to the width of the kernels we plotted above. The default behavior tries to guess a good value using a common reference rule, but it may be helpful to try larger or smaller values:

# %%
sns.kdeplot(df['Age'], label="bw: Default")
sns.kdeplot(df['Age'], bw=.1, label="bw: 0.1")
sns.kdeplot(df['Age'], bw=2, label="bw: 2")
plt.legend();

# %% [markdown]
# **Histogram with rugplot**

# %%
sns.distplot(df['Age'], rug=True);
# Out:
# /home/muhammadtaqi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Bivariate
#
# It can also be useful to visualize a bivariate distribution of two variables. The easiest way to do this in seaborn is to just use the `jointplot()` function, which creates a multi-panel figure that shows both the bivariate (or joint) relationship between two variables along with the univariate (or marginal) distribution of each on separate axes.
#
# **Scatterplots ( ~ rugplots in 2D )**
#
# `Jointplot()` defaults to a scatterplot.

# %%
sns.jointplot(x="Age", y="Fare", data=df);
# Out:
# /home/muhammadtaqi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/muhammadtaqi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# **Hexbin Plots ( ~ Histogram in 2D )**
#
# The bivariate analogue of a histogram is known as a “hexbin” plot, because it shows the counts of observations that fall within hexagonal bins. This plot works best with relatively large datasets. It’s available through the matplotlib plt.hexbin function and as a style in jointplot(). It looks best with a white background:

# %%
sns.jointplot(x="Age", y="Fare", data=df, kind="hex", color="k");
# Out:
# /home/muhammadtaqi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/muhammadtaqi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# **Contours ( ~ KDE in 2D )**

# %%
sns.jointplot(x="Age", y="Survived", data=df, kind="kde");

# %%
f, ax = plt.subplots(figsize=(6, 6))
sns.kdeplot(df.Age, df.Survived, ax=ax)
sns.rugplot(df.Age, color="g", ax=ax)
sns.rugplot(df.Survived, vertical=True, ax=ax);

# %% [markdown]
# ### Pairwise Bivariate

# %%
sns.pairplot(df);

# %%
cor.head()   # jahanv pr -ve hai udhr -ve correlation hai.
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033207 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.069809 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.331339  0.083081  0.018443
# Age             0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
# SibSp          -0.057527 -0.035322  0.083081 -0.232625  1.000000  0.414838
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.091566
# SibSp        0.159651

# %%
# plt.figure(figszie=(9,6))
cor = df.corr()
sns.heatmap(cor, annot=True);

# survived is response var and rest is explonatry variables.

# %% [markdown]
# # Visualizations against each variable type

# %% [markdown]
# #### Categorical Variable

# %%
sns.countplot(x='Sex',data=df);

# %% [markdown]
# #### 2 categorical Variables

# %%
survived_class = pd.crosstab(index=df["Survived"], 
                            columns=df["Title"],
                             margins=True) 
survived_class
# Out:
# Title     Capt  Col  Countess  Don  Dr  Jonkheer  Lady  Major  Master  Miss  \
# Survived
# 0            1    1         0    1   4         1     0      1      17    55
# 1            0    1         1    0   3         0     1      1      23   127
# All          1    2         1    1   7         1     1      2      40   182
#
# Title     Mlle  Mme   Mr  Mrs  Ms  Rev  Sir  All
# Survived
# 0            0    0  436   26   0    6    0  549
# 1            2    1   81   99   1    0    1  342
# All          2    1  517  125   1    6    1  891

# %% [markdown]
# #### 1 Numerical variable

# %%
sns.distplot(df['Fare']);
# Out:
# /home/muhammadtaqi/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# #### 2 Numerical variables

# %%
sns.regplot(x="Age", y="Fare", data=df);

# %% [markdown]
# #### 1 numeric and 1 categorical variable

# %%
sns.boxplot(data=df, x='Pclass', y='Age');
